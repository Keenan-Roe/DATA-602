# %%
#Q1 Fix all the syntax and logical errors in the given source code 
#add comments to explain your reasoning

# This program gets three test scores and displays their average.  It congratulates the user if the 
# average is a high score. The high score variable holds the value that is considered a high score.

HIGH_SCORE = 95

#I needed to change the input from a string to a floating point opperator and add test3 as a variable 
# Get the test scores.
test1 = float(input('Enter the score for test 1: '))
test2 = float(input('Enter the score for test 2: '))
test3 = float(input('Enter the score for test 3: '))
# Calculate the average test score.
average = (test1 + test2 + test3 )/ 3
# Print the average.
print('The average score is', average)
# If the average is a high score,
# congratulate the user.
if average >= HIGH_SCORE:
    print('Congratulations!')
print('That is a great average!')
# Out:
# Enter the score for test 1:  99
# Enter the score for test 2:  95
# Enter the score for test 3:  98
# The average score is 97.33333333333333
# Congratulations!
# That is a great average!

# %%
#Q2
# The area of a rectangle is the rectangle’s length times its width. 
# Write a program that asks for the length and width of two rectangles 
# and prints to the user the area of both rectangles. 

#give a prompt to the user
print("This program will take in the length and width of two rectangles.\nPlease enter the length and width of the first and then the length and width of the second rectangle")
# get the dims of the two rectangles 
length1 = float(input('Enter the length of the first rectangle: ')) 
width1 = float(input('Enter the width of the first rectangle: ' )) 

length2 = float(input('Enter the length of the second rectangle: ')) 
width2 = float(input('Enter the width of the second rectangle: ')) 

#basice math for the area of both 
area1 = (length1 * width1) 
area2 = (length2 * width2)

# print the result for the user 
print( "The area of the first rectangle is",  area1, "and the areas of the second triangle is", area2 )
# Out:
# This program will take in the length and width of two rectangles.
# Please enter the length and width of the first and then the length and width of the second rectangle
# Enter the length of the first rectangle:  10
# Enter the width of the first rectangle:  5
# Enter the length of the second rectangle:  8
# Enter the width of the second rectangle:  4
# The area of the first rectangle is 50.0 and the areas of the second triangle is 32.0

# %%
#Q3 
#Ask a user to enter their first name and their age and assign it to the variables name and age. 
#The variable name should be a string and the variable age should be an int.  

name = str(input("Enter your first name: " ))
age = int(input("Enter your age: ")) 

print("Happy birthday, ", name, "! You are ", age, " years old today!", sep="")

#Using the variables name and age, print a message to the user stating something along the lines of:
# "Happy birthday, name!  You are age years old today!"
# Out:
# Enter your first name:  Keenan
# Enter your age:  10
# Happy birthday, Keenan! You are 10 years old today!
